# %% [markdown]
# See fail on project design document näidete jaoks by Kea

# %%
import requests 
import os
from datetime import datetime, timedelta
import json
import pandas as pd
import csv

# %%
def get_metadata():
    lines = 50000
    with open(f"arxiv-metadata-oai-snapshot.json", 'r') as f:
        for line in f:
            if lines == 0:
                break
            lines -= 1
            yield line

# %%
metadata = get_metadata()
metadata
# Out:
# <generator object get_metadata at 0x0000025D9F183060>

# %%
# Json to df, drop abstract, license, report-no, comments, update_date, submitter, authors (bc there is authors_parsed)

authors_parsed = []
categories	 = []
doi = []
ids = []
journalref = []
titles = []
versions = []
for paper in metadata:
    metaDict = json.loads(paper)
    ids.append(metaDict['id'])
    doi.append(metaDict['doi'])
    titles.append(metaDict['title'])
    journalref.append(metaDict['journal-ref'])
    authors_parsed.append(metaDict['authors_parsed'])
    categories.append(metaDict['categories'])
    versions.append(metaDict['versions'])

df = pd.DataFrame({'id' : ids, 'doi': doi, 'title' : titles, 'authors_parsed': authors_parsed, 'categories' : categories, 'journal_ref': journalref, 'versions': versions})
df.head()
# Out:
#           id                         doi  \
# 0  0704.0001  10.1103/PhysRevD.76.013009
# 1  0704.0002                        None
# 2  0704.0003                        None
# 3  0704.0004                        None
# 4  0704.0005                        None
#
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 1           Sparsity-certifying Graph Decompositions
# 2  The evolution of the Earth-Moon system based o...
# 3  A determinant of Stirling cycle numbers counts...
# 4  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
#
#                                       authors_parsed       categories  \
# 0  [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...           hep-ph
# 1           [[Streinu, Ileana, ], [Theran, Louis, ]]    math.CO cs.CG
# 2                                 [[Pan, Hongjun, ]]   physics.gen-ph
# 3                                [[Callan, David, ]]          math.CO
# 4  [[Abu-Shammala, Wael, ], [Torchinsky, Alberto, ]]  math.CA math.FA
#
#                                  journal_ref  \
# 0                   Phys.Rev.D76:013009,2007
# 1                                       None
# 2                                       None
# 3                                       None
# 4  Illinois J. Math. 52 (2008) no.2, 681-689
#
#                                             versions
# 0  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...
# 1  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...
# 2  [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...
# 3  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...
# 4  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...

# %%
#df.describe() # Siit on näha, et esineb ka duplikaate.

# %%
df[df.title.duplicated(keep=False)]
# Out:
#               id                               doi  \
# 1228   0704.1229    10.1016/j.physletb.2007.10.028
# 2181   0704.2182  10.1111/j.1365-2966.2007.12016.x
# 2185   0704.2186  10.1111/j.1365-2966.2007.12016.x
# 3881   0704.3882   10.1016/j.nuclphysb.2007.06.009
# 4622   0705.0620                              None
# ...          ...                               ...
# 45337  0801.3010                              None
# 48043  0802.0746                10.1214/07-STS235C
# 48044  0802.0747                10.1214/07-STS235A
# 48046  0802.0749                10.1214/07-STS235D
# 48840  0802.1543                    10.1086/529187
#
#                                                    title  \
# 1228   High-precision covariant one-boson-exchange po...
# 2181   Metal and molecule cooling in simulations of s...
# 2185   Metal and molecule cooling in simulations of s...
# 3881   Screening masses in the SU(3) pure gauge theor...
# 4622   Generating Unexpected Spin Echoes in Dipolar S...
# ...                                                  ...
# 45337  A partial $A_\infty$-structure on the cohomolo...
# 48043  Comment: Bayesian Checking of the Second Level...
# 48044  Comment: Bayesian Checking of the Second Level...
# 48046  Comment: Bayesian Checking of the Second Level...
# 48840    Tidal Evolution of Close-in Extra-Solar Planets
#
#                                           authors_parsed categories  \
# 1228             [[Gross, Franz, ], [Stadler, Alfred, ]]    nucl-th
# 2181   [[Maio, U., ], [Dolag, K., ], [Ciardi, B., ], ...   astro-ph
# 2185   [[Maio, U., ], [Dolag, K., ], [Ciardi, B., ], ...   astro-ph
# 3881   [[Falcone, Rossella, ], [Fiore, Roberto, ], [G...    hep-lat
# 4622   [[Li, Dale, ], [Dementyev, A. E., ], [Dong, Ya...   quant-ph
# ...                                                  ...        ...
# 45337                    [[Vejdemo-Johansson, Mikael, ]]    math.AT
# 48043                                    [[Evans, M., ]]    stat.ME
# 48044                               [[Gelman, Andrew, ]]    stat.ME
# 48046                            [[Johnson, Valen E., ]]    stat.ME
# 48840  [[Jackson, Brian, ], [Greenberg, Richard, ], [...   astro-ph
#
#                                              journal_ref  \
# 1228                         Phys.Lett.B657:176-179,2007
# 2181                                                None
# 2185             Mon.Not.Roy.Astron.Soc.379:963-973,2007
# 3881                           Nucl.Phys.B785:19-33,2007
# 4622                                                None
# ...                                                  ...
# 45337                                               None
# 48043  Statistical Science 2007, Vol. 22, No. 3, 344-348
# 48044  Statistical Science 2007, Vol. 22, No. 3, 349-352
# 48046  Statistical Science 2007, Vol. 22, No. 3, 353-358
# 48840                                               None
#
#                                                 versions
# 1228   [{'version': 'v1', 'created': 'Tue, 10 Apr 200...
# 2181   [{'version': 'v1', 'created': 'Tue, 17 Apr 200...
# 2185   [{'version': 'v1', 'created': 'Tue, 17 Apr 200...
# 3881   [{'version': 'v1', 'created': 'Mon, 30 Apr 200...
# 4622   [{'version': 'v1', 'created': 'Fri, 4 May 2007...
# ...                                                  ...
# 45337  [{'version': 'v1', 'created': 'Sat, 19 Jan 200...
# 48043  [{'version': 'v1', 'created': 'Wed, 6 Feb 2008...
# 48044  [{'version': 'v1', 'created': 'Wed, 6 Feb 2008...
# 48046  [{'version': 'v1', 'created': 'Wed, 6 Feb 2008...
# 48840  [{'version': 'v1', 'created': 'Mon, 11 Feb 200...
#
# [71 rows x 7 columns]

# %%
df[df.title.duplicated()]
# Out:
#               id                               doi  \
# 2185   0704.2186  10.1111/j.1365-2966.2007.12016.x
# 4669   0705.0667     10.1103/PhysRevLett.98.190401
# 16843  0707.3673                              None
# 17949  0708.0098        10.1214/009053606000001046
# 17972  0708.0121        10.1214/009053606000001055
# 17975  0708.0124        10.1214/009053606000001064
# 17983  0708.0132        10.1214/009053606000001073
# 18138  0708.0287        10.1214/088342306000000538
# 18139  0708.0288        10.1214/088342306000000547
# 18187  0708.0336        10.1214/088342306000000600
# 18189  0708.0338        10.1214/088342306000000628
# 20236  0708.2385  10.1111/j.1365-2966.2007.12366.x
# 21628  0708.3777        10.1214/088342307000000069
# 21630  0708.3779        10.1214/088342307000000050
# 21747  0708.3896                              None
# 25479  0709.3214   10.1016/j.nuclphysb.2007.10.028
# 26099  0709.3834                              None
# 29032  0710.2085   10.1016/j.nuclphysb.2007.06.009
# 29872  0710.2925                              None
# 29889  0710.2942                              None
# 31959  0710.5012        10.1214/088342307000000195
# 31960  0710.5013        10.1214/088342307000000186
# 31962  0710.5015        10.1214/088342307000000159
# 31963  0710.5016        10.1214/088342307000000168
# 34817  0711.1925     10.1088/1126-6708/2008/01/025
# 35081  0711.2189    10.1016/j.physletb.2007.12.046
# 35350  0711.2458        10.1051/0004-6361:20067028
# 37133  0711.4241                              None
# 37449  0711.4557                              None
# 38555  0712.0634         10.1007/s00601-008-0312-9
# 38693  0712.0772         10.1017/S1743921308016864
# 40885  0712.2964  10.1111/j.1365-2966.2008.12870.x
# 41414  0712.3493    10.1103/PhysRevLett.100.231803
# 42312  0712.4391                              None
# 42693  0801.0366        10.1142/9789812818805_0022
# 45260  0801.2933                              None
# 45265  0801.2938                              None
# 45337  0801.3010                              None
# 48044  0802.0747                10.1214/07-STS235A
# 48046  0802.0749                10.1214/07-STS235D
# 48840  0802.1543                    10.1086/529187
#
#                                                    title  \
# 2185   Metal and molecule cooling in simulations of s...
# 4669   Generating Unexpected Spin Echoes in Dipolar S...
# 16843  The Computation of All 4R Serial Spherical Wri...
# 17949  Discussion of ``2004 IMS Medallion Lecture: Lo...
# 17972  Discussion of ``2004 IMS Medallion Lecture: Lo...
# 17975  Discussion of ``2004 IMS Medallion Lecture: Lo...
# 17983  Discussion of ``2004 IMS Medallion Lecture: Lo...
# 18138  Comment: Expert Elicitation for Reliable Syste...
# 18139  Comment: Expert Elicitation for Reliable Syste...
# 18187  Comment: Monitoring Networked Applications Wit...
# 18189  Comment: Monitoring Networked Applications Wit...
# 20236  A centimetre-wave excess over free-free emissi...
# 21628  Comment: Fisher Lecture: Dimension Reduction i...
# 21630  Comment: Fisher Lecture: Dimension Reduction i...
# 21747  The Isoconditioning Loci of Planar Three-DOF P...
# 25479  Hard spectator interactions in B to pi pi at o...
# 26099  Back-in-time dynamics of the cluster IE 0657-5...
# 29032  Screening masses in the SU(3) pure gauge theor...
# 29872  Bridging over p-wave pi-production and weak pr...
# 29889     Rapidity gap survival in the black-disk regime
# 31959  Comment: Struggles with Survey Weighting and R...
# 31960  Comment: Struggles with Survey Weighting and R...
# 31962  Comment: Struggles with Survey Weighting and R...
# 31963  Comment: Struggles with Survey Weighting and R...
# 34817      Phase structure of twisted Eguchi-Kawai model
# 35081  Search for Lepton Flavor Violating tau Decays ...
# 35350               The environs of the HII region Gum31
# 37133  Radial Dependence of Extinction in Parent Gala...
# 37449  On Outage Behavior of Wideband Slow-Fading Cha...
# 38555  High-precision covariant one-boson-exchange po...
# 38693  3D SPH simulations of grain growth in protopla...
# 40885  Gamma-Ray Emission from PWNe Interacting with ...
# 41414       Measurement of the Decay B- --> D*0 e- nubar
# 42312  The formation of spiral arms and rings in barr...
# 42693  The formation of spiral arms and rings in barr...
# 45260  Structure and Evolution of the Opacity of Spir...
# 45265                  Spitzer's View of Edge-on Spirals
# 45337  A partial $A_\infty$-structure on the cohomolo...
# 48044  Comment: Bayesian Checking of the Second Level...
# 48046  Comment: Bayesian Checking of the Second Level...
# 48840    Tidal Evolution of Close-in Extra-Solar Planets
#
#                                           authors_parsed  \
# 2185   [[Maio, U., ], [Dolag, K., ], [Ciardi, B., ], ...
# 4669   [[Li, Dale, ], [Dementyev, A. E., ], [Dong, Ya...
# 16843  [[Chablat, Damien, , IRCCyN], [Angeles, Jorge,...
# 17949  [[Clémençon, Stéphan, ], [Lugosi, Gábor, ], [V...
# 17972             [[Shen, Xiaotong, ], [Wang, Lifeng, ]]
# 17975                              [[Tsybakov, A. B., ]]
# 17983                            [[van de Geer, Sara, ]]
# 18138                              [[Koehler, Andrew, ]]
# 18139                                 [[Wang, Wenbin, ]]
# 18187  [[Lawrence, Earl, ], [Michailidis, George, ], ...
# 18189                                      [[Yu, Bin, ]]
# 20236  [[Casassus, S., ], [Nyman, L. -A., ], [Dickins...
# 21628                                     [[Li, Bing, ]]
# 21630    [[Li, Lexin, ], [Nachtsheim, Christopher J., ]]
# 21747  [[Chablat, Damien, , IRCCyN], [Wenger, Philipp...
# 25479                               [[Pilipp, Volker, ]]
# 26099                                  [[Nusser, Adi, ]]
# 29032  [[Falcone, Rossella, ], [Fiore, Roberto, ], [G...
# 29872                [[Nakamura, Satoshi. X., , TRIUMF]]
# 29889  [[Frankfurt, L., , Tel Aviv U.], [Hyde, C. E.,...
# 31959         [[Breidt, F. Jay, ], [Opsomer, Jean D., ]]
# 31960                          [[Little, Roderick J., ]]
# 31962                              [[Lohr, Sharon L., ]]
# 31963                           [[Pfeffermann, Danny, ]]
# 34817  [[Azeyanagi, Tatsuo, ], [Hanada, Masanori, ], ...
# 35081                                 [[Miyazaki, Y., ]]
# 35350  [[Cappa, C., ], [Niemela, V. S., ], [Amorin, R...
# 37133  [[Onic, Dusan, ], [Arbutina, Bojan, ], [Urosev...
# 37449             [[Zhang, Wenyi, ], [Mitra, Urbashi, ]]
# 38555            [[Gross, Franz, ], [Stadler, Alfred, ]]
# 38693  [[Laibe, Guillaume, , CRAL], [Gonzalez, Jean-F...
# 40885                 [[Bartko, H., ], [Bednarek, W., ]]
# 41414    [[The BABAR Collaboration, , ], [Aubert, B., ]]
# 42312  [[Romero-Gomez, M., ], [Athanassoula, E., ], [...
# 42693                             [[Romero-Gomez, M., ]]
# 45260  [[Holwerda, B. W., ], [Gonzalez, R. A., ], [Ke...
# 45265  [[Holwerda, B. W., ], [de Jong, R. S., ], [Set...
# 45337                    [[Vejdemo-Johansson, Mikael, ]]
# 48044                               [[Gelman, Andrew, ]]
# 48046                            [[Johnson, Valen E., ]]
# 48840  [[Jackson, Brian, ], [Greenberg, Richard, ], [...
#
#                        categories  \
# 2185                     astro-ph
# 4669   quant-ph cond-mat.mes-hall
# 16843                       cs.RO
# 17949    q-fin.RM math.ST stat.TH
# 17972    q-fin.RM math.ST stat.TH
# 17975    q-fin.RM math.ST stat.TH
# 17983    q-fin.RM math.ST stat.TH
# 18138                     stat.ME
# 18139                     stat.ME
# 18187                     stat.ME
# 18189                     stat.ME
# 20236                    astro-ph
# 21628                     stat.ME
# 21630                     stat.ME
# 21747                       cs.RO
# 25479                      hep-ph
# 26099                    astro-ph
# 29032                     hep-lat
# 29872              nucl-th hep-ph
# 29889                      hep-ph
# 31959                     stat.ME
# 31960                     stat.ME
# 31962                     stat.ME
# 31963                     stat.ME
# 34817              hep-lat hep-th
# 35081                      hep-ex
# 35350                    astro-ph
# 37133                    astro-ph
# 37449               cs.IT math.IT
# 38555                     nucl-th
# 38693                    astro-ph
# 40885                    astro-ph
# 41414                      hep-ex
# 42312                    astro-ph
# 42693                    astro-ph
# 45260                    astro-ph
# 45265                    astro-ph
# 45337                     math.AT
# 48044                     stat.ME
# 48046                     stat.ME
# 48840                    astro-ph
#
#                                              journal_ref  \
# 2185             Mon.Not.Roy.Astron.Soc.379:963-973,2007
# 4669                  Phys. Rev. Lett. 98, 190401 (2007)
# 16843  Dans 2nd Workshop on Computational Kinematics ...
# 17949  Annals of Statistics 2006, Vol. 34, No. 6, 267...
# 17972  Annals of Statistics 2006, Vol. 34, No. 6, 267...
# 17975  Annals of Statistics 2006, Vol. 34, No. 6, 268...
# 17983  Annals of Statistics 2006, Vol. 34, No. 6, 268...
# 18138  Statistical Science 2006, Vol. 21, No. 4, 454-455
# 18139  Statistical Science 2006, Vol. 21, No. 4, 456-459
# 18187  Statistical Science 2006, Vol. 21, No. 4, 479-482
# 18189  Statistical Science 2006, Vol. 21, No. 4, 483-484
# 20236                                               None
# 21628    Statistical Science 2007, Vol. 22, No. 1, 32-35
# 21630    Statistical Science 2007, Vol. 22, No. 1, 36-39
# 21747  Dans 29th Design Automation Conference - ASME ...
# 25479                        Nucl.Phys.B794:154-188,2008
# 26099                                               None
# 29032                                PoSLAT2007:183,2007
# 29872                              ECONFC070910:264,2007
# 29889                                               None
# 31959  Statistical Science 2007, Vol. 22, No. 2, 168-170
# 31960  Statistical Science 2007, Vol. 22, No. 2, 171-174
# 31962  Statistical Science 2007, Vol. 22, No. 2, 175-178
# 31963  Statistical Science 2007, Vol. 22, No. 2, 179-183
# 34817                                  JHEP0801:025,2008
# 35081                        Phys.Lett.B660:154-160,2008
# 35350                                               None
# 37133  Revista Mexicana de Astronomia y Astrofisica V...
# 37449                                               None
# 38555                      Few Body Syst.44:295-298,2008
# 38693  Dans Proceedings of IAU Symp. 249 - Exoplanets...
# 40885                                               None
# 41414                      Phys.Rev.Lett.100:231803,2008
# 42312                                               None
# 42693                                               None
# 45260                                               None
# 45265                                               None
# 45337                                               None
# 48044  Statistical Science 2007, Vol. 22, No. 3, 349-352
# 48046  Statistical Science 2007, Vol. 22, No. 3, 353-358
# 48840                                               None
#
#                                                 versions
# 2185   [{'version': 'v1', 'created': 'Tue, 17 Apr 200...
# 4669   [{'version': 'v1', 'created': 'Fri, 4 May 2007...
# 16843  [{'version': 'v1', 'created': 'Wed, 25 Jul 200...
# 17949  [{'version': 'v1', 'created': 'Wed, 1 Aug 2007...
# 17972  [{'version': 'v1', 'created': 'Wed, 1 Aug 2007...
# 17975  [{'version': 'v1', 'created': 'Wed, 1 Aug 2007...
# 17983  [{'version': 'v1', 'created': 'Wed, 1 Aug 2007...
# 18138  [{'version': 'v1', 'created': 'Thu, 2 Aug 2007...
# 18139  [{'version': 'v1', 'created': 'Thu, 2 Aug 2007...
# 18187  [{'version': 'v1', 'created': 'Thu, 2 Aug 2007...
# 18189  [{'version': 'v1', 'created': 'Thu, 2 Aug 2007...
# 20236  [{'version': 'v1', 'created': 'Fri, 17 Aug 200...
# 21628  [{'version': 'v1', 'created': 'Tue, 28 Aug 200...
# 21630  [{'version': 'v1', 'created': 'Tue, 28 Aug 200...
# 21747  [{'version': 'v1', 'created': 'Wed, 29 Aug 200...
# 25479  [{'version': 'v1', 'created': 'Thu, 20 Sep 200...
# 26099  [{'version': 'v1', 'created': 'Mon, 24 Sep 200...
# 29032  [{'version': 'v1', 'created': 'Wed, 10 Oct 200...
# 29872  [{'version': 'v1', 'created': 'Mon, 15 Oct 200...
# 29889  [{'version': 'v1', 'created': 'Tue, 16 Oct 200...
# 31959  [{'version': 'v1', 'created': 'Fri, 26 Oct 200...
# 31960  [{'version': 'v1', 'created': 'Fri, 26 Oct 200...
# 31962  [{'version': 'v1', 'created': 'Fri, 26 Oct 200...
# 31963  [{'version': 'v1', 'created': 'Fri, 26 Oct 200...
# 34817  [{'version': 'v1', 'created': 'Tue, 13 Nov 200...
# 35081  [{'version': 'v1', 'created': 'Wed, 14 Nov 200...
# 35350  [{'version': 'v1', 'created': 'Thu, 15 Nov 200...
# 37133  [{'version': 'v1', 'created': 'Tue, 27 Nov 200...
# 37449  [{'version': 'v1', 'created': 'Wed, 28 Nov 200...
# 38555  [{'version': 'v1', 'created': 'Wed, 5 Dec 2007...
# 38693  [{'version': 'v1', 'created': 'Wed, 5 Dec 2007...
# 40885  [{'version': 'v1', 'created': 'Tue, 18 Dec 200...
# 41414  [{'version': 'v1', 'created': 'Thu, 20 Dec 200...
# 42312  [{'version': 'v1', 'created': 'Fri, 28 Dec 200...
# 42693  [{'version': 'v1', 'created': 'Wed, 2 Jan 2008...
# 45260  [{'version': 'v1', 'created': 'Fri, 18 Jan 200...
# 45265  [{'version': 'v1', 'created': 'Fri, 18 Jan 200...
# 45337  [{'version': 'v1', 'created': 'Sat, 19 Jan 200...
# 48044  [{'version': 'v1', 'created': 'Wed, 6 Feb 2008...
# 48046  [{'version': 'v1', 'created': 'Wed, 6 Feb 2008...
# 48840  [{'version': 'v1', 'created': 'Mon, 11 Feb 200...

# %%
# Remove the duplicates
df = df[~df.title.duplicated()]

# %%
# Missing values
df.isnull().sum()
# Out:
# id                    0
# doi               19562
# title                 0
# authors_parsed        0
# categories            0
# journal_ref       24330
# versions              0
# dtype: int64

# %%
# Enforcing types
df['doi']= df['doi'].astype('str')
df['id']= df['id'].astype('str')
df['title']= df['title'].astype('str')
df['authors_parsed']= df['authors_parsed'].astype('str')
df['categories']= df['categories'].astype('str')
df['journal_ref']= df['journal_ref'].astype('str')
df['versions']= df['versions'].astype('str')

# %%
len(df)
# Out:
# 49959

# %%
# Show records where title is only one word
df[~df.title.str.contains(" ")]
# Out:
#               id                             doi                title  \
# 1378   0704.1379                            None     U-max-Statistics
# 6895   0705.2893   10.1088/1475-7516/2007/09/001             K-Bounce
# 11607  0706.2921                            None             Herwig++
# 12165  0706.3479                            None      Hypocomputation
# 18146  0708.0295      10.1214/088342306000000664          Reliability
# 19134  0708.1283      10.1103/PhysRevD.77.121501       Pre-Holography
# 20173  0708.2322                            None                 Zero
# 24790  0709.2525                            None     H-Decompositions
# 24931  0709.2666   10.1088/1475-7516/2008/02/010          Spinflation
# 26881  0709.4616                            None                Charm
# 28279  0710.1332                            None     Polyexponentials
# 29304  0710.2357                            None             Overhang
# 30737  0710.3790  10.1016/j.physletb.2007.10.038           f(R)-Brane
# 31399  0710.4452                            None             f0(1370)
# 32322  0710.5375                            None    Superbosonization
# 35922  0711.3030                            None             Diamonds
# 37448  0711.4556      10.1016/j.ppnp.2008.02.001           Charmonium
# 37549  0711.4657       10.1007/s10485-008-9136-5                Icons
# 38543  0712.0622                            None          Filtrations
# 42323  0712.4402                            None             Judgment
# 42645  0801.0318                            None     SUSY@LHC.CERN.CH
# 43607  0801.1280                            None          LR-algebras
# 44376  0801.2049                            None  Nanothermomechanics
# 44484  0801.2157   10.1088/1126-6708/2008/02/059          ISS-flation
# 45702  0801.3375      10.1103/PhysRevD.77.123508          DBI-essence
# 46031  0801.3704                            None            $q$-Chaos
# 47283  0801.4956   10.1088/1126-6708/2008/06/028         Q-instantons
#
#                                           authors_parsed  \
# 1378      [['Lao', 'Wei', ''], ['Mayer', 'Michael', '']]
# 6895   [['Abramo', 'L. Raul', ''], ['Peter', 'Patrick...
# 11607  [['Gigg', 'Martyn', '', 'IPPP, Durham Universi...
# 12165                            [['Love', 'David', '']]
# 18146  [['Keller-McNulty', 'Sallie', ''], ['Wilson', ...
# 19134  [['Kay', 'Bernard S.', '', 'York'], ['Larkin',...
# 20173                          [['Quznetsov', 'G.', '']]
# 24790                         [['Gilbert', 'Jesse', '']]
# 24931  [['Easson', 'Damien A.', ''], ['Gregory', 'Rut...
# 26881                          [['Mahlke', 'Hanna', '']]
# 28279                 [['Boyadzhiev', 'Khristo N.', '']]
# 29304   [['Paterson', 'Mike', ''], ['Zwick', 'Uri', '']]
# 30737  [['Afonso', 'V. I.', ''], ['Bazeia', 'D.', '']...
# 31399  [['Bugg', 'D. V.', '', 'Queen Mary, University...
# 32322                   [['Sommers', 'Hans-Jürgen', '']]
# 35922                        [['Shelah', 'Saharon', '']]
# 37448                        [['Voloshin', 'M. B.', '']]
# 37549                          [['Lack', 'Stephen', '']]
# 38543  [['Coculescu', 'Delia', ''], ['Nikeghbali', 'A...
# 42323                    [["O'Flanagan", 'Ruadhan', '']]
# 42645                       [['Spiropulu', 'Maria', '']]
# 43607  [['Burde', 'Dietrich', ''], ['Dekimpe', 'Karel...
# 44376                    [['Trzesowski', 'Andrzej', '']]
# 44484                    [['Craig', 'Nathaniel J.', '']]
# 45702  [['Martin', 'Jerome', ''], ['Yamaguchi', 'Masa...
# 46031  [['Junge', 'Marius', ''], ['Lee', 'Hun Hee', '']]
# 47283  [['Bergshoeff', 'E. A.', ''], ['Hartong', 'J.'...
#
#                               categories  \
# 1378             math.ST math.PR stat.TH
# 6895               astro-ph gr-qc hep-th
# 11607                             hep-ph
# 12165                              cs.OH
# 18146                            stat.ME
# 19134       hep-th gr-qc math-ph math.MP
# 20173                     physics.gen-ph
# 24790                              cs.DM
# 24931       hep-th astro-ph gr-qc hep-ph
# 26881                             hep-ex
# 28279                    math.NA math.CA
# 29304    math.HO math-ph math.CO math.MP
# 30737                             hep-th
# 31399                             hep-ex
# 32322                 cond-mat.stat-mech
# 35922                            math.LO
# 37448                             hep-ph
# 37549                            math.CT
# 38543                            math.PR
# 42323              math.PR cs.AI math.LO
# 42645                             hep-ex
# 43607                            math.RA
# 44376  cond-mat.mtrl-sci math-ph math.MP
# 44484             hep-th astro-ph hep-ph
# 45702       hep-th astro-ph gr-qc hep-ph
# 46031                    math.OA math.FA
# 47283                             hep-th
#
#                                              journal_ref  \
# 1378                                                None
# 6895                                   JCAP0709:001,2007
# 11607                                               None
# 12165                                               None
# 18146  Statistical Science 2006, Vol. 21, No. 4, 427-427
# 19134                           Phys.Rev.D77:121501,2008
# 20173                                               None
# 24790                                               None
# 24931                                 JCAP 0802:010,2008
# 26881                Acta Phys.Polon.Supp.1:331-338,2008
# 28279                                               None
# 29304                                               None
# 30737                          Phys.Lett.B658:71-76,2007
# 31399                                               None
# 32322    ACTA PHYSICA POLONICA B vol.38 (2007) 1001-1006
# 35922  Proceedings of the American Mathematical Socie...
# 37448                Prog.Part.Nucl.Phys.61:455-511,2008
# 37549  Applied Categorical Structures, 18(3):289-307,...
# 38543                                               None
# 42323                                               None
# 42645                                               None
# 43607                                               None
# 44376  Journal of Technical Physics, vol. 50, 3-4, pp...
# 44484                                  JHEP0802:059,2008
# 45702                           Phys.Rev.D77:123508,2008
# 46031                                               None
# 47283                                 JHEP 0806:028,2008
#
#                                                 versions
# 1378   [{'version': 'v1', 'created': 'Wed, 11 Apr 200...
# 6895   [{'version': 'v1', 'created': 'Sun, 20 May 200...
# 11607  [{'version': 'v1', 'created': 'Wed, 20 Jun 200...
# 12165  [{'version': 'v1', 'created': 'Sat, 23 Jun 200...
# 18146  [{'version': 'v1', 'created': 'Thu, 2 Aug 2007...
# 19134  [{'version': 'v1', 'created': 'Thu, 9 Aug 2007...
# 20173  [{'version': 'v1', 'created': 'Fri, 17 Aug 200...
# 24790  [{'version': 'v1', 'created': 'Mon, 17 Sep 200...
# 24931  [{'version': 'v1', 'created': 'Mon, 17 Sep 200...
# 26881  [{'version': 'v1', 'created': 'Fri, 28 Sep 200...
# 28279  [{'version': 'v1', 'created': 'Fri, 5 Oct 2007...
# 29304  [{'version': 'v1', 'created': 'Fri, 12 Oct 200...
# 30737  [{'version': 'v1', 'created': 'Fri, 19 Oct 200...
# 31399  [{'version': 'v1', 'created': 'Wed, 24 Oct 200...
# 32322  [{'version': 'v1', 'created': 'Mon, 29 Oct 200...
# 35922  [{'version': 'v1', 'created': 'Mon, 19 Nov 200...
# 37448  [{'version': 'v1', 'created': 'Wed, 28 Nov 200...
# 37549  [{'version': 'v1', 'created': 'Thu, 29 Nov 200...
# 38543  [{'version': 'v1', 'created': 'Tue, 4 Dec 2007...
# 42323  [{'version': 'v1', 'created': 'Fri, 28 Dec 200...
# 42645  [{'version': 'v1', 'created': 'Tue, 1 Jan 2008...
# 43607  [{'version': 'v1', 'created': 'Tue, 8 Jan 2008...
# 44376  [{'version': 'v1', 'created': 'Mon, 14 Jan 200...
# 44484  [{'version': 'v1', 'created': 'Mon, 14 Jan 200...
# 45702  [{'version': 'v1', 'created': 'Tue, 22 Jan 200...
# 46031  [{'version': 'v1', 'created': 'Thu, 24 Jan 200...
# 47283  [{'version': 'v1', 'created': 'Thu, 31 Jan 200...

# %%
# Remove records where title is one word
df = df[df.title.str.contains(" ")]

# %%
len(df)
# Out:
# 49932

# %%
# Find records with missing authors
df[df['authors_parsed'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, doi, title, authors_parsed, categories, journal_ref, versions]
# Index: []

# %%
df.head()
# Out:
#           id                         doi  \
# 0  0704.0001  10.1103/PhysRevD.76.013009
# 1  0704.0002                        None
# 2  0704.0003                        None
# 3  0704.0004                        None
# 4  0704.0005                        None
#
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 1           Sparsity-certifying Graph Decompositions
# 2  The evolution of the Earth-Moon system based o...
# 3  A determinant of Stirling cycle numbers counts...
# 4  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
#
#                                       authors_parsed       categories  \
# 0  [['Balázs', 'C.', ''], ['Berger', 'E. L.', '']...           hep-ph
# 1  [['Streinu', 'Ileana', ''], ['Theran', 'Louis'...    math.CO cs.CG
# 2                           [['Pan', 'Hongjun', '']]   physics.gen-ph
# 3                          [['Callan', 'David', '']]          math.CO
# 4  [['Abu-Shammala', 'Wael', ''], ['Torchinsky', ...  math.CA math.FA
#
#                                  journal_ref  \
# 0                   Phys.Rev.D76:013009,2007
# 1                                       None
# 2                                       None
# 3                                       None
# 4  Illinois J. Math. 52 (2008) no.2, 681-689
#
#                                             versions
# 0  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...
# 1  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...
# 2  [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...
# 3  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...
# 4  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...

# %%
# credits for the category map to this notebook: https://www.kaggle.com/code/artgor/arxiv-metadata-exploration
# https://arxiv.org/help/api/user-manual
subdomain_map = {'astro-ph': 'Astrophysics',
'astro-ph.CO': 'Cosmology and Nongalactic Astrophysics',
'astro-ph.EP': 'Earth and Planetary Astrophysics',
'astro-ph.GA': 'Astrophysics of Galaxies',
'astro-ph.HE': 'High Energy Astrophysical Phenomena',
'astro-ph.IM': 'Instrumentation and Methods for Astrophysics',
'astro-ph.SR': 'Solar and Stellar Astrophysics',
'cond-mat.dis-nn': 'Disordered Systems and Neural Networks',
'cond-mat.mes-hall': 'Mesoscale and Nanoscale Physics',
'cond-mat.mtrl-sci': 'Materials Science',
'cond-mat.other': 'Other Condensed Matter',
'cond-mat.quant-gas': 'Quantum Gases',
'cond-mat.soft': 'Soft Condensed Matter',
'cond-mat.stat-mech': 'Statistical Mechanics',
'cond-mat.str-el': 'Strongly Correlated Electrons',
'cond-mat.supr-con': 'Superconductivity',
'cs.AI': 'Artificial Intelligence',
'cs.AR': 'Hardware Architecture',
'cs.CC': 'Computational Complexity',
'cs.CE': 'Computational Engineering, Finance, and Science',
'cs.CG': 'Computational Geometry',
'cs.CL': 'Computation and Language',
'cs.CR': 'Cryptography and Security',
'cs.CV': 'Computer Vision and Pattern Recognition',
'cs.CY': 'Computers and Society',
'cs.DB': 'Databases',
'cs.DC': 'Distributed, Parallel, and Cluster Computing',
'cs.DL': 'Digital Libraries',
'cs.DM': 'Discrete Mathematics',
'cs.DS': 'Data Structures and Algorithms',
'cs.ET': 'Emerging Technologies',
'cs.FL': 'Formal Languages and Automata Theory',
'cs.GL': 'General Literature',
'cs.GR': 'Graphics',
'cs.GT': 'Computer Science and Game Theory',
'cs.HC': 'Human-Computer Interaction',
'cs.IR': 'Information Retrieval',
'cs.IT': 'Information Theory',
'cs.LG': 'Machine Learning',
'cs.LO': 'Logic in Computer Science',
'cs.MA': 'Multiagent Systems',
'cs.MM': 'Multimedia',
'cs.MS': 'Mathematical Software',
'cs.NA': 'Numerical Analysis',
'cs.NE': 'Neural and Evolutionary Computing',
'cs.NI': 'Networking and Internet Architecture',
'cs.OH': 'Other Computer Science',
'cs.OS': 'Operating Systems',
'cs.PF': 'Performance',
'cs.PL': 'Programming Languages',
'cs.RO': 'Robotics',
'cs.SC': 'Symbolic Computation',
'cs.SD': 'Sound',
'cs.SE': 'Software Engineering',
'cs.SI': 'Social and Information Networks',
'cs.SY': 'Systems and Control',
'econ.EM': 'Econometrics',
'econ.GN': 'General Economics',
'econ.TH': 'Theoretical Economics',
'eess.AS': 'Audio and Speech Processing',
'eess.IV': 'Image and Video Processing',
'eess.SP': 'Signal Processing',
'gr-qc': 'General Relativity and Quantum Cosmology',
'hep-ex': 'High Energy Physics - Experiment',
'hep-lat': 'High Energy Physics - Lattice',
'hep-ph': 'High Energy Physics - Phenomenology',
'hep-th': 'High Energy Physics - Theory',
'math.AC': 'Commutative Algebra',
'math.AG': 'Algebraic Geometry',
'math.AP': 'Analysis of PDEs',
'math.AT': 'Algebraic Topology',
'math.CA': 'Classical Analysis and ODEs',
'math.CO': 'Combinatorics',
'math.CT': 'Category Theory',
'math.CV': 'Complex Variables',
'math.DG': 'Differential Geometry',
'math.DS': 'Dynamical Systems',
'math.FA': 'Functional Analysis',
'math.GM': 'General Mathematics',
'math.GN': 'General Topology',
'math.GR': 'Group Theory',
'math.GT': 'Geometric Topology',
'math.HO': 'History and Overview',
'math.IT': 'Information Theory',
'math.KT': 'K-Theory and Homology',
'math.LO': 'Logic',
'math.MG': 'Metric Geometry',
'math.MP': 'Mathematical Physics',
'math.NA': 'Numerical Analysis',
'math.NT': 'Number Theory',
'math.OA': 'Operator Algebras',
'math.OC': 'Optimization and Control',
'math.PR': 'Probability',
'math.QA': 'Quantum Algebra',
'math.RA': 'Rings and Algebras',
'math.RT': 'Representation Theory',
'math.SG': 'Symplectic Geometry',
'math.SP': 'Spectral Theory',
'math.ST': 'Statistics Theory',
'math-ph': 'Mathematical Physics',
'nlin.AO': 'Adaptation and Self-Organizing Systems',
'nlin.CD': 'Chaotic Dynamics',
'nlin.CG': 'Cellular Automata and Lattice Gases',
'nlin.PS': 'Pattern Formation and Solitons',
'nlin.SI': 'Exactly Solvable and Integrable Systems',
'nucl-ex': 'Nuclear Experiment',
'nucl-th': 'Nuclear Theory',
'physics.acc-ph': 'Accelerator Physics',
'physics.ao-ph': 'Atmospheric and Oceanic Physics',
'physics.app-ph': 'Applied Physics',
'physics.atm-clus': 'Atomic and Molecular Clusters',
'physics.atom-ph': 'Atomic Physics',
'physics.bio-ph': 'Biological Physics',
'physics.chem-ph': 'Chemical Physics',
'physics.class-ph': 'Classical Physics',
'physics.comp-ph': 'Computational Physics',
'physics.data-an': 'Data Analysis, Statistics and Probability',
'physics.ed-ph': 'Physics Education',
'physics.flu-dyn': 'Fluid Dynamics',
'physics.gen-ph': 'General Physics',
'physics.geo-ph': 'Geophysics',
'physics.hist-ph': 'History and Philosophy of Physics',
'physics.ins-det': 'Instrumentation and Detectors',
'physics.med-ph': 'Medical Physics',
'physics.optics': 'Optics',
'physics.plasm-ph': 'Plasma Physics',
'physics.pop-ph': 'Popular Physics',
'physics.soc-ph': 'Physics and Society',
'physics.space-ph': 'Space Physics',
'q-bio.BM': 'Biomolecules',
'q-bio.CB': 'Cell Behavior',
'q-bio.GN': 'Genomics',
'q-bio.MN': 'Molecular Networks',
'q-bio.NC': 'Neurons and Cognition',
'q-bio.OT': 'Other Quantitative Biology',
'q-bio.PE': 'Populations and Evolution',
'q-bio.QM': 'Quantitative Methods',
'q-bio.SC': 'Subcellular Processes',
'q-bio.TO': 'Tissues and Organs',
'q-fin.CP': 'Computational Finance',
'q-fin.EC': 'Economics',
'q-fin.GN': 'General Finance',
'q-fin.MF': 'Mathematical Finance',
'q-fin.PM': 'Portfolio Management',
'q-fin.PR': 'Pricing of Securities',
'q-fin.RM': 'Risk Management',
'q-fin.ST': 'Statistical Finance',
'q-fin.TR': 'Trading and Market Microstructure',
'quant-ph': 'Quantum Physics',
'stat.AP': 'Applications',
'stat.CO': 'Computation',
'stat.ME': 'Methodology',
'stat.ML': 'Machine Learning',
'stat.OT': 'Other Statistics',
'stat.TH': 'Statistics Theory'}

# %%
# Kea tegi käsitsi selle pealt https://arxiv.org/category_taxonomy
# Req docsis oli https://confluence.egi.eu/display/EGIG/Scientific+Disciplines aga tundub suur käsitöö

scientific_domain_map = {
# Physics
'astro-ph': 'Physics',
'astro-ph.CO': 'Physics',
'astro-ph.EP': 'Physicss',
'astro-ph.GA': 'Physics',
'astro-ph.HE': 'Physics',
'astro-ph.IM': 'Physics',
'astro-ph.SR': 'Physicss',
'cond-mat.dis-nn': 'Physics',
'cond-mat.mes-hall': 'Physics',
'cond-mat.mtrl-sci': 'Physics',
'cond-mat.other': 'Physics',
'cond-mat.quant-gas': 'Physics',
'cond-mat.soft': 'Physics',
'cond-mat.stat-mech': 'Physics',
'cond-mat.str-el': 'Physics',
'cond-mat.supr-con': 'Physics',
'gr-qc': 'Physics',
'hep-ex': 'Physics',
'hep-lat': 'Physics',
'hep-ph': 'Physics',
'hep-th': 'Physics',
'nlin.AO': 'Physics',
'nlin.CD': 'Physics',
'nlin.CG': 'Physics',
'nlin.PS': 'Physics',
'nlin.SI': 'Physics',
'nucl-ex': 'Physics',
'nucl-th': 'Physics',
'physics.acc-ph': 'Physics',
'physics.ao-ph': 'Physics',
'physics.app-ph': 'Physics',
'physics.atm-clus': 'Physics',
'physics.atom-ph': 'Physics',
'physics.bio-ph': 'Physics',
'physics.chem-ph': 'Physics',
'physics.class-ph': 'Physics',
'physics.comp-ph': 'Physics',
'physics.data-an': 'Physics',
'physics.ed-ph': 'Physics',
'physics.flu-dyn': 'Physics',
'physics.gen-ph': 'Physics',
'physics.geo-ph': 'Physics',
'physics.hist-ph': 'Physics',
'physics.ins-det': 'Physics',
'physics.med-ph': 'Physics',
'physics.optics': 'Physics',
'physics.plasm-ph': 'Physics',
'physics.pop-ph': 'Physics',
'physics.soc-ph': 'Physics',
'physics.space-ph': 'Physics',
'quant-ph': 'Physics',
# Computer Science
'cs.AI': 'Computer Science',
'cs.AR': 'Computer Science',
'cs.CC': 'Computer Science',
'cs.CE': 'Computer Science',
'cs.CG': 'Computer Science',
'cs.CL': 'Computer Science',
'cs.CR': 'Computer Science',
'cs.CV': 'Computer Science',
'cs.CY': 'Computer Science',
'cs.DB': 'Computer Science',
'cs.DC': 'Computer Science',
'cs.DL': 'Computer Science',
'cs.DM': 'Computer Science',
'cs.DS': 'Computer Science',
'cs.ET': 'Computer Science',
'cs.FL': 'Computer Science',
'cs.GL': 'Computer Science',
'cs.GR': 'Computer Science',
'cs.GT': 'Computer Science',
'cs.HC': 'Computer Science',
'cs.IR': 'Computer Science',
'cs.IT': 'Computer Science',
'cs.LG': 'Computer Science',
'cs.LO': 'Computer Science',
'cs.MA': 'Computer Science',
'cs.MM': 'Computer Science',
'cs.MS': 'Computer Science',
'cs.NA': 'Computer Science',
'cs.NE': 'Computer Science',
'cs.NI': 'Computer Science',
'cs.OH': 'Computer Science',
'cs.OS': 'Computer Science',
'cs.PF': 'Computer Science',
'cs.PL': 'Computer Science',
'cs.RO': 'Computer Science',
'cs.SC': 'Computer Science',
'cs.SD': 'Computer Science',
'cs.SE': 'Computer Science',
'cs.SI': 'Computer Science',
'cs.SY': 'Computer Science',
# Economics
'econ.EM': 'Economics',
'econ.GN': 'Economics',
'econ.TH': 'Economics',
# Electrical Engineering and Systems Science
'eess.AS': 'Electrical Engineering and Systems Science',
'eess.IV': 'Electrical Engineering and Systems Science',
'eess.SP': 'Electrical Engineering and Systems Science',
# Mathematics
'math.AC': 'Mathematics',
'math.AG': 'Mathematics',
'math.AP': 'Mathematics',
'math.AT': 'Mathematics',
'math.CA': 'Mathematics',
'math.CO': 'Mathematics',
'math.CT': 'Mathematics',
'math.CV': 'Mathematics',
'math.DG': 'Mathematics',
'math.DS': 'Mathematics',
'math.FA': 'Mathematics',
'math.GM': 'Mathematics',
'math.GN': 'Mathematics',
'math.GR': 'Mathematics',
'math.GT': 'Mathematics',
'math.HO': 'Mathematics',
'math.IT': 'Mathematics',
'math.KT': 'Mathematics',
'math.LO': 'Mathematics',
'math.MG': 'Mathematics',
'math.MP': 'Mathematics',
'math.NA': 'Mathematics',
'math.NT': 'Mathematics',
'math.OA': 'Mathematics',
'math.OC': 'Mathematics',
'math.PR': 'Mathematics',
'math.QA': 'Mathematics',
'math.RA': 'Mathematics',
'math.RT': 'Mathematics',
'math.SG': 'Mathematics',
'math.SP': 'Mathematics',
'math.ST': 'Mathematics',
'math-ph': 'Mathematics',
# Biology
'q-bio.BM': 'Quantitative Biology',
'q-bio.CB': 'Quantitative Biology',
'q-bio.GN': 'Quantitative Biology',
'q-bio.MN': 'Quantitative Biology',
'q-bio.NC': 'Quantitative Biology',
'q-bio.OT': 'Quantitative Biology',
'q-bio.PE': 'Quantitative Biology',
'q-bio.QM': 'Quantitative Biology',
'q-bio.SC': 'Quantitative Biology',
'q-bio.TO': 'Quantitative Biology',
# Finance
'q-fin.CP': 'Quantitative Finance',
'q-fin.EC': 'Quantitative Finance',
'q-fin.GN': 'Quantitative Finance',
'q-fin.MF': 'Quantitative Finance',
'q-fin.PM': 'Quantitative Finance',
'q-fin.PR': 'Quantitative Finance',
'q-fin.RM': 'Quantitative Finance',
'q-fin.ST': 'Quantitative Finance',
'q-fin.TR': 'Quantitative Finance',
# Statistics
'stat.AP': 'Statistics',
'stat.CO': 'Statistics',
'stat.ME': 'Statistics',
'stat.ML': 'Statistics',
'stat.OT': 'Statistics',
'stat.TH': 'Statistics'}

# %%
# Categorie codes to categories and to scientific domains
# NBNB! Võtan praegu ainult need, kus üks category code. Tegelikult peaks categories ära splittima ja mingi lahenduse mõtlema, kuidas ka teisi arvestada või kas lubame mitut domaini.
# # Siin jäävad praegu kõik mitme kategooria koodiga välja.
df = df[~df.categories.str.contains(" ")]
#df.head()

# %%
df['domain']= df['categories'].map(scientific_domain_map)

# %%
df.head()
# Out:
#           id                         doi  \
# 0  0704.0001  10.1103/PhysRevD.76.013009
# 2  0704.0003                        None
# 3  0704.0004                        None
# 5  0704.0006  10.1103/PhysRevA.75.043613
# 6  0704.0007  10.1103/PhysRevD.76.044016
#
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 2  The evolution of the Earth-Moon system based o...
# 3  A determinant of Stirling cycle numbers counts...
# 5  Bosonic characters of atomic Cooper pairs acro...
# 6  Polymer Quantum Mechanics and its Continuum Limit
#
#                                       authors_parsed         categories  \
# 0  [['Balázs', 'C.', ''], ['Berger', 'E. L.', '']...             hep-ph
# 2                           [['Pan', 'Hongjun', '']]     physics.gen-ph
# 3                          [['Callan', 'David', '']]            math.CO
# 5      [['Pong', 'Y. H.', ''], ['Law', 'C. K.', '']]  cond-mat.mes-hall
# 6  [['Corichi', 'Alejandro', ''], ['Vukasinac', '...              gr-qc
#
#                 journal_ref  \
# 0  Phys.Rev.D76:013009,2007
# 2                      None
# 3                      None
# 5                      None
# 6  Phys.Rev.D76:044016,2007
#
#                                             versions       domain
# 0  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...      Physics
# 2  [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...      Physics
# 3  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  Mathematics
# 5  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...      Physics
# 6  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...      Physics

# %%
df['subdomain'] = df['categories'].map(subdomain_map)

# %%
df.drop(['categories'], axis=1, inplace=True)
df.head()
# Out:
#           id                         doi  \
# 0  0704.0001  10.1103/PhysRevD.76.013009
# 2  0704.0003                        None
# 3  0704.0004                        None
# 5  0704.0006  10.1103/PhysRevA.75.043613
# 6  0704.0007  10.1103/PhysRevD.76.044016
#
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 2  The evolution of the Earth-Moon system based o...
# 3  A determinant of Stirling cycle numbers counts...
# 5  Bosonic characters of atomic Cooper pairs acro...
# 6  Polymer Quantum Mechanics and its Continuum Limit
#
#                                       authors_parsed  \
# 0  [['Balázs', 'C.', ''], ['Berger', 'E. L.', '']...
# 2                           [['Pan', 'Hongjun', '']]
# 3                          [['Callan', 'David', '']]
# 5      [['Pong', 'Y. H.', ''], ['Law', 'C. K.', '']]
# 6  [['Corichi', 'Alejandro', ''], ['Vukasinac', '...
#
#                 journal_ref  \
# 0  Phys.Rev.D76:013009,2007
# 2                      None
# 3                      None
# 5                      None
# 6  Phys.Rev.D76:044016,2007
#
#                                             versions       domain  \
# 0  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...      Physics
# 2  [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...      Physics
# 3  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  Mathematics
# 5  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...      Physics
# 6  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...      Physics
#
#                                   subdomain
# 0       High Energy Physics - Phenomenology
# 2                           General Physics
# 3                             Combinatorics
# 5           Mesoscale and Nanoscale Physics
# 6  General Relativity and Quantum Cosmology
